// %%
import {ObjectId, MongoClient } from 'mongodb'

const uri = 'mongodb+srv://adamo:(G0rillaz)!@luster0.5q5kdhg.mongodb.net/appingles_qa?retryWrites=true&w=majority';

const client = new MongoClient(uri);


async function connectToDatabase() {
    try {
        // Connect to MongoDB
        await client.connect();
        console.log('Successfully connected to MongoDB.');
        
        // Get database reference
        const db = client.db('appingles_qa');
        
        // Get collection reference
        const collection = db.collection('conversations');
        
        return { client, db, collection };
    } catch (error) {
        console.error('Error connecting to MongoDB:', error);
        throw error;
    }
}

const { _, db, collection } = await connectToDatabase()

const object = await collection.findOne({ id: 'myid' });
console.log(object)
// Out:
// Successfully connected to MongoDB.
// {
//   _id: new ObjectId("6755130fa8eae1ada39fd742"),
//   characterCard: {
//     data: {
//       name: "La Serpiente",
//       description: "Misteriosa, sabia y enigmática. Actúa como un mediador y guía del Principito en su viaje. Ofrece ayuda al Principito para regresar a su planeta, pero su ayuda tiene un costo.",
//       scenario: "",
//       first_mes: "*Te encuentras a la serpiente*\nhola {{user}}?",
//       creator_notes: "",
//       mes_example: "",
//       alternate_greetings: [],
//       tags: [],
//       system_prompt: "",
//       post_history_instructions: ""
//     }
//   },
//   createdAt: 2024-12-08T03:31:27.414Z,
//   updatedAt: 2025-01-05T19:32:01.414Z,
//   __v: 0,
//   assets: {
//     image: {
//       url: "https://fal.media/files/rabbit/YpoglL8U9zmNQJ8z7Yuju.jpeg"
//     }
//   },
//   conversationType: "rolePlay",
//   id: "myid",
//   lang: "",
//   metaApp: {
//     isPublished: false,
//     isPublic: false,
// ...
